# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Example of morphological file
df = pd.read_csv("/home/pablo/code/aramis/graph_topology/results/exp_t050_d050/csv/morphology/morphology_sample1.csv")
df
# Out:
#      centroid-0    centroid-1  area   perimeter  area_bbox  area_convex  \
# 0   5411.797619  10222.011905    84   40.183766        153          112
# 1   5435.388489  10154.856115   278   75.296465        462          331
# 2   5489.383598  10132.431217   378   82.953319        600          424
# 3   5493.222222  10148.777778    45   23.213203         81           45
# 4   5398.115044  10390.663717   565   99.195959        837          611
# 5   5486.991182  10380.178131   567   99.781746        810          610
# 6   5478.772727  10450.227273    44   23.213203         81           44
# 7   5481.000000  10443.000000    25   16.970563         49           25
# 8   5493.277778  10490.722222    36   20.384776         64           36
# 9   5387.292135  10741.228464   267   67.982756        399          290
# 10  5436.665455  10709.749091   275   66.083261        361          290
# 11  5466.004505  10892.072072   222   74.710678        480          275
# ...

# %%
# Example of topological file
df = pd.read_csv("/home/pablo/code/aramis/graph_topology/results/exp_t050_d050/csv/topology/topology_exp_t050_d050.csv")
df
# Out:
#    order  size  diameter  radius  average_shortest_path_length   density  \
# 0      9    13         4       2                      2.000000  0.361111
# 1     14    21         7       4                      3.098901  0.230769
# 2      4     4         2       1                      1.333333  0.666667
#
#    graph_clique_number  graph_number_of_cliques  transitivity  \
# 0                    3                        6           0.5
# 1                    3                       10           0.5
# 2                    3                        2           0.6
#
#    local_efficiency  ...  closeness_centrality_min  closeness_centrality_max  \
# 0          0.645370  ...                  0.363636                  0.727273
# 1          0.662698  ...                  0.250000                  0.433333
# 2          0.583333  ...                  0.600000                  1.000000
#
#    closeness_centrality_qt95  closeness_centrality_qt75  \
# ...
